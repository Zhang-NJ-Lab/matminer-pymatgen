# %%
# https://github.com/WSukmas/Workshop_ECPRL/blob/main/pymatgen_matminer.ipynb
from pymatgen.ext.matproj import MPRester
from pymatgen.io.cif import CifParser
import matminer
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %config InlineBackend.figure_format='retina'
# %matplotlib Inline

# %%
with MPRester("foqWelVbBoixU9suS6DAz6xg7RASqTVq") as mpr:
    data = mpr.summary.search(
        formula=["Fe2O3"],
        fields=["formula_pretty", "formation_energy_per_atom", "band_gap"],
    )
data = pd.DataFrame(data)
data
# Out:
# Retrieving SummaryDoc documents:   0%|          | 0/26 [00:00<?, ?it/s]
#                           0                                                 1  \
# 0   (formula_pretty, Fe2O3)  (formation_energy_per_atom, -0.8474868450000003)
# 1   (formula_pretty, Fe2O3)  (formation_energy_per_atom, -1.5389699480000005)
# 2   (formula_pretty, Fe2O3)   (formation_energy_per_atom, -1.179299471666667)
# 3   (formula_pretty, Fe2O3)  (formation_energy_per_atom, -1.5297528905000006)
# 4   (formula_pretty, Fe2O3)  (formation_energy_per_atom, -1.5942413437500007)
# 5   (formula_pretty, Fe2O3)  (formation_energy_per_atom, -1.4817387886250004)
# 6   (formula_pretty, Fe2O3)  (formation_energy_per_atom, -1.5912518724999998)
# 7   (formula_pretty, Fe2O3)  (formation_energy_per_atom, -1.2040484616666665)
# 8   (formula_pretty, Fe2O3)  (formation_energy_per_atom, -1.4175868379999996)
# 9   (formula_pretty, Fe2O3)  (formation_energy_per_atom, -1.6224374475000005)
# ...

# %%
with MPRester("foqWelVbBoixU9suS6DAz6xg7RASqTVq") as mpr:
     shortC = mpr.summary.search(band_gap=1.2)
    
data = pd.DataFrame(shortC)
data

# with MPRester("foqWelVbBoixU9suS6DAz6xg7RASqTVq") as mpr:
#     data = mpr.summary.search(formula=["Fe2O3"], fields=["formula_pretty", "formation_energy_per_atom", "band_gap"],)
# Out:
# Retrieving SummaryDoc documents: 0it [00:00, ?it/s]
# Empty DataFrame
# Columns: []
# Index: []
